# %%
import pandas as pd
from tqdm import tqdm

# %%
cwd = '/Users/lincoln.harris/code/cerebra/cerebra/wrkdir/'

# %%
# what does the COSMIC database actually look like? 
database = pd.read_csv(cwd + "cosmic_db_egfr_sub.csv", delimiter = ',')
database
# Out:
#     Gene name Accession Number  Gene CDS length  HGNC ID  \
# 0        EGFR  ENST00000275493             3633     3236
# 1        EGFR  ENST00000275493             3633     3236
# 2        EGFR  ENST00000275493             3633     3236
# 3        EGFR  ENST00000275493             3633     3236
# 4        EGFR  ENST00000275493             3633     3236
# 5        EGFR  ENST00000275493             3633     3236
# 6        EGFR  ENST00000275493             3633     3236
# 7        EGFR  ENST00000275493             3633     3236
# 8        EGFR  ENST00000275493             3633     3236
# 9        EGFR  ENST00000275493             3633     3236
# 10       EGFR  ENST00000275493             3633     3236
# 11       EGFR  ENST00000275493             3633     3236
# 12       EGFR  ENST00000275493             3633     3236
# 13       EGFR  ENST00000275493             3633     3236
# 14       EGFR  ENST00000275493             3633     3236
# ...

# %%
for i in range(0, len(database.index)):
    curr = database['Gene name'].iloc[i]
    print(curr)
# Out:
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# EGFR
# ...

# %%
looping=True
i=0
while looping:
    curr = database['Sample name'].iloc[i]
    if curr == 'YUKLAB':
        looping=False
    i+=1

# %%
looping=True
i=0
while looping:
    curr = database['Sample name'].iloc[i]
    if curr == 'foobar':
        looping=False
    i+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-987c420e06c9> in <module>()
#       2 i=0
#       3 while looping:
# ----> 4     curr = database['Sample name'].iloc[i]
#       5     if curr == 'foobar':
#       6         looping=False
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ...

# %%
for i in range(0,len(database.index)):
    curr = database['Sample name'].iloc[i]
    if curr == 'YUKLAB':
        AA_sub = database['Mutation AA'].iloc[i]
