# %%
import pandas as pd

# %%
pd.read_json('/Users/lincoln.harris/Desktop/cerebra_100_bench.json')
# Out:
#                                                              KRAS
# A10_1001000407  [ENSP00000308495.3:p.(Asp119Gly), ENSP00000256...
# A10_1001000408  [ENSP00000308495.3:p.(Gly77Asp), ENSP000002560...
# A10_1001000412  [ENSP00000256078.4:p.(Val29_Asp30insHisGly), E...
# A10_B000863                                                    []
# A10_B001470                                                    []
# A10_B001474                                                    []
# A10_B001545                                                    []
# A10_B001554                                                    []
# A10_B001558                                                    []
# A10_B002572                                                    []
# A10_B003070                                                    []
# A10_B003071     [ENSP00000308495.3:p.(Leu53Ser), ENSP000002560...
# A10_B003115                                                    []
# ...

# %%
pd.read_csv('/Users/lincoln.harris/Desktop/cerebra_100_bench.csv')
# Out:
#         Unnamed: 0                                               KRAS
# 0   A10_1001000407  ['ENSP00000256078.4:p.(Ala83Thr)', 'ENSP000002...
# 1   A10_1001000408  ['ENSP00000256078.4:p.(Gly77Asp)', 'ENSP000003...
# 2   A10_1001000412  ['ENSP00000452512.1:p.(Val29_Asp30insHisGly)',...
# 3      A10_B000863                                                 []
# 4      A10_B001470                                                 []
# 5      A10_B001474                                                 []
# 6      A10_B001545                                                 []
# 7      A10_B001554                                                 []
# 8      A10_B001558                                                 []
# 9      A10_B002572                                                 []
# 10     A10_B003070                                                 []
# 11     A10_B003071  ['ENSP00000308495.3:p.(Leu53Ser)', 'ENSP000002...
# ...
